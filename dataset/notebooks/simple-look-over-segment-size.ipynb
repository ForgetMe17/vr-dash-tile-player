# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
face_list = np.load("../segment_size/1-2-Front-180s-tile_1-gop_1-temp.npy")
disp_data = face_list[0][0][0][1::2]

# %%
disp_data = disp_data[1:100]
plt.bar(np.arange(len(disp_data)), disp_data)
#plt.ylim(0, 10e3)
# Out:
# <BarContainer object of 99 artists>

# %%
disp_data[1:100]
# Out:
# array(['100351', '106339', '107310', '109036', '107446', '107956',
#        '107517', '107797', '108673', '108840', '108008', '108408',
#        '108872', '110362', '109822', '110757', '111266', '111586',
#        '111800', '111650', '111820', '111660', '114373', '115591',
#        '116273', '116148', '115503', '118038', '118039', '128904',
#        '131063', '128568', '126821', '124138', '123013', '122409',
#        '122487', '122235', '122136', '121998', '121600', '121755',
#        '121333', '121583', '121509', '121574', '122947', '123216',
#        '123549', '123362', '123168', '123079', '123179', '123437',
#        '124012', '124063', '123953', '123930', '123743', '140480',
#        '137769', '136459', '133953', '133065', '131931', '131765',
#        '133678', '133863', '134107', '134487', '134580', '136299',
#        '135270', '135562', '135974', '135922', '136106', '136698',
#        '136143', '136450', '136059', '137084', '137798', '137270',
# ...

# %%
np.reshape(face_list[0][0][0][0:200], (-1, 2))
# Out:
# array([['seg-1.m4s', '97769'],
#        ['seg-2.m4s', '100351'],
#        ['seg-3.m4s', '106339'],
#        ['seg-4.m4s', '107310'],
#        ['seg-5.m4s', '109036'],
#        ['seg-6.m4s', '107446'],
#        ['seg-7.m4s', '107956'],
#        ['seg-8.m4s', '107517'],
#        ['seg-9.m4s', '107797'],
#        ['seg-10.m4s', '108673'],
#        ['seg-11.m4s', '108840'],
#        ['seg-12.m4s', '108008'],
#        ['seg-13.m4s', '108408'],
#        ['seg-14.m4s', '108872'],
#        ['seg-15.m4s', '110362'],
#        ['seg-16.m4s', '109822'],
#        ['seg-17.m4s', '110757'],
#        ['seg-18.m4s', '111266'],
#        ['seg-19.m4s', '111586'],
#        ['seg-20.m4s', '111800'],
#        ['seg-21.m4s', '111650'],
#        ['seg-22.m4s', '111820'],
#        ['seg-23.m4s', '111660'],
#        ['seg-24.m4s', '114373'],
#        ['seg-25.m4s', '115591'],
#        ['seg-26.m4s', '116273'],
#        ['seg-27.m4s', '116148'],
#        ['seg-28.m4s', '115503'],
# ...
